# %% [markdown]
# # Instalação
#
# Para executar este notebook é necessário usar o comando `pip install basemap` possuindo o arquivo 'basemap-1.3.3-pp38-pypy38_pp73-win_amd64.whl' e o software qgis instalado, de forma a gerar os mapas utilizando os arquivos shapefile contidos na pasta Brasil.

# %%
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
import seaborn as sns
import numpy as np
import datetime

# %% [markdown]
# # Funções de formatação e pipelines para organizar os dados

# %%
def get_usinas_dataframe()->pd.DataFrame:
    out_df = pd.DataFrame()
    for path in glob('FATOR_DE_CAPACIDADE\*.csv'):
        aux_df = pd.read_csv(path, sep=';', parse_dates=['din_instante'])
        aux_df.index = aux_df['din_instante']
        out_df = pd.concat([out_df, aux_df])

    return out_df

# %%
def get_usina_solar_pipeline(main_df:pd.DataFrame, nome_usina:str)->pd.DataFrame:
    return main_df.query('nom_tipousina=="Solar"').query('nom_usina_conjunto == @nome_usina')

# %%
main_df = get_usinas_dataframe()

# %%
main_df = main_df.drop('din_instante', axis=1)

# %%
conjunto_janauba_df = main_df.pipe(get_usina_solar_pipeline, nome_usina='Conj. Janaúba')

# %%
conjunto_futura_df = main_df.pipe(get_usina_solar_pipeline, nome_usina='Conj. Futura')

# %%
main_df
# Out:
#                     id_subsistema        nom_subsistema id_estado nom_estado  \
# din_instante
# 2022-01-01 00:00:00             N                 Norte        MA   MARANHAO
# 2022-01-01 00:00:00            NE              Nordeste        BA      BAHIA
# 2022-01-01 00:00:00            NE              Nordeste        BA      BAHIA
# 2022-01-01 00:00:00            NE              Nordeste        BA      BAHIA
# 2022-01-01 00:00:00            NE              Nordeste        BA      BAHIA
# ...                           ...                   ...       ...        ...
# 2023-04-19 23:00:00            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 2023-04-19 23:00:00            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 2023-04-19 23:00:00            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 2023-04-19 23:00:00            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
# 2023-04-19 23:00:00            SE  Sudeste/Centro-Oeste        SP  SAO PAULO
#
#                                nom_pontoconexao nom_localizacao  \
# din_instante
# 2022-01-01 00:00:00            MIRANDA II500kVA             NaN
# 2022-01-01 00:00:00      PINDAI II - 230 kV (A)        Interior
# 2022-01-01 00:00:00      IGAPORA II - 69 kV (A)        Interior
# 2022-01-01 00:00:00     IGAPORA II - 230 kV (B)        Interior
# 2022-01-01 00:00:00   U.SOBRADINHO - 500 kV (A)        Interior
# ...                                         ...             ...
# 2023-04-19 23:00:00    TRES IRMAOS - 138 kV (A)             NaN
# 2023-04-19 23:00:00        DRACENA - 138 kV (A)             NaN
# 2023-04-19 23:00:00       GETULINA - 138 kV (A)             NaN
# 2023-04-19 23:00:00  AGUA VERMELHA - 138 kV (A)             NaN
# 2023-04-19 23:00:00    TRES IRMAOS - 138 kV (A)             NaN
#
#                      val_latitudesecoletora  val_longitudesecoletora  \
# din_instante
# 2022-01-01 00:00:00               -2.727222               -42.596389
# 2022-01-01 00:00:00              -14.353933               -42.575842
# 2022-01-01 00:00:00              -14.208409               -42.636807
# 2022-01-01 00:00:00              -14.102794               -42.609369
# 2022-01-01 00:00:00               -9.751812               -41.006198
# ...                                     ...                      ...
# 2023-04-19 23:00:00              -20.790444               -51.529266
# 2023-04-19 23:00:00              -21.450214               -51.587776
# 2023-04-19 23:00:00              -21.893809               -49.863684
# 2023-04-19 23:00:00              -20.195849               -50.032683
# 2023-04-19 23:00:00              -20.620000               -51.300000
#
#                      val_latitudepontoconexao  val_longitudepontoconexao  \
# din_instante
# 2022-01-01 00:00:00                 -3.566219                 -44.535478
# 2022-01-01 00:00:00                -14.415433                 -42.607767
# 2022-01-01 00:00:00                -14.027222                 -42.629444
# 2022-01-01 00:00:00                -14.027222                 -42.629444
# 2022-01-01 00:00:00                 -9.436083                 -40.829167
# ...                                       ...                        ...
# 2023-04-19 23:00:00                -20.656389                 -51.482778
# 2023-04-19 23:00:00                -21.457222                 -51.526667
# 2023-04-19 23:00:00                -21.855464                 -49.838358
# 2023-04-19 23:00:00                -19.867222                 -50.350000
# 2023-04-19 23:00:00                -20.656389                 -51.482778
#
#                     nom_modalidadeoperacao nom_tipousina  \
# din_instante
# 2022-01-01 00:00:00     Conjunto de Usinas        Eólica
# 2022-01-01 00:00:00     Conjunto de Usinas        Eólica
# 2022-01-01 00:00:00     Conjunto de Usinas        Eólica
# 2022-01-01 00:00:00     Conjunto de Usinas        Eólica
# 2022-01-01 00:00:00     Conjunto de Usinas        Eólica
# ...                                    ...           ...
# 2023-04-19 23:00:00     Conjunto de Usinas         Solar
# 2023-04-19 23:00:00     Conjunto de Usinas         Solar
# 2023-04-19 23:00:00     Conjunto de Usinas         Solar
# 2023-04-19 23:00:00     Conjunto de Usinas         Solar
# 2023-04-19 23:00:00     Conjunto de Usinas         Solar
#
#                         nom_usina_conjunto  val_geracaoprogramada  \
# din_instante
# 2022-01-01 00:00:00    Conj. Paulino Neves                   50.5
# 2022-01-01 00:00:00           Conj. Abil I                    NaN
# 2022-01-01 00:00:00         Conj. Alvorada                    9.0
# 2022-01-01 00:00:00           Conj. Araçás                   25.5
# 2022-01-01 00:00:00          Conj. Arizona                    7.0
# ...                                    ...                    ...
# 2023-04-19 23:00:00         Conj. Castilho                    0.0
# 2023-04-19 23:00:00          Conj. Dracena                    0.0
# 2023-04-19 23:00:00          Conj. Guaimbê                    0.0
# 2023-04-19 23:00:00     Conj. Pedranópolis                    0.0
# 2023-04-19 23:00:00  Conj. Pereira Barreto                    0.0
#
#                      val_geracaoverificada  val_capacidadeinstalada  \
# din_instante
# 2022-01-01 00:00:00                101.353                   426.00
# 2022-01-01 00:00:00                  0.000                    71.10
# 2022-01-01 00:00:00                  0.000                    38.40
# 2022-01-01 00:00:00                 62.804                   167.70
# 2022-01-01 00:00:00                  0.000                    76.23
# ...                                    ...                      ...
# 2023-04-19 23:00:00                  0.080                   210.70
# 2023-04-19 23:00:00                  0.000                    81.00
# 2023-04-19 23:00:00                  0.000                   150.00
# 2023-04-19 23:00:00                  0.000                    90.36
# 2023-04-19 23:00:00                  0.000                   203.52
#
#                      val_fatorcapacidade
# din_instante
# 2022-01-01 00:00:00             0.237918
# 2022-01-01 00:00:00             0.000000
# 2022-01-01 00:00:00             0.000000
# 2022-01-01 00:00:00             0.374502
# 2022-01-01 00:00:00             0.000000
# ...                                  ...
# 2023-04-19 23:00:00             0.000380
# 2023-04-19 23:00:00             0.000000
# 2023-04-19 23:00:00             0.000000
# 2023-04-19 23:00:00             0.000000
# 2023-04-19 23:00:00             0.000000
#
# [2030328 rows x 17 columns]

# %% [markdown]
# # Exibindo usinas solares e eolicas

# %%
group_by_usina_solar = main_df.query('nom_tipousina=="Solar"').groupby(['nom_usina_conjunto', 'id_estado']).agg({'val_capacidadeinstalada':'last', 'val_latitudesecoletora':'last', 'val_longitudesecoletora':'last'}).sort_values(by='val_capacidadeinstalada',ascending=False)

# %%
group_by_usina_eolica = main_df.query('nom_tipousina=="Eólica"').groupby(['nom_usina_conjunto', 'id_estado']).agg({'val_capacidadeinstalada':'last', 'val_latitudesecoletora':'last', 'val_longitudesecoletora':'last'}).sort_values(by='val_capacidadeinstalada',ascending=False)

# %%
group_by_usina_solar.dropna()
# Out:
#                                         val_capacidadeinstalada  \
# nom_usina_conjunto           id_estado
# Conj. Janaúba                MG                     1020.360000
# Conj. São Gonçalo            PI                      575.725333
# Conj. Lar do Sol             MG                      494.970000
# Conj. Sol do Sertão          BA                      415.030000
# Conj. Pirapora               MG                      329.000000
# Conj. Alex                   CE                      278.397000
# Conj. Serra do Mel C         RN                      240.590000
# Conj. Rio Alto               PB                      216.000000
# Conj. São Gonçalo A          PI                      215.160000
# Conj. Castilho               SP                      210.700000
# Conj. Nova Olinda            PI                      210.000000
# Conj. Pereira Barreto        SP                      203.520000
# Conj. Lavras                 CE                      198.000000
# Conj. Ituverava              BA                      196.000000
# Conj. FV SJP                 PI                      186.050000
# Conj. São Basílio (Solar)    PI                      185.638000
# Conj. Brígida                PE                      163.000000
# Conj. Juazeiro Solar 2       BA                      157.068000
# Conj. Guaimbê                SP                      150.000000
# Conj. Boa Hora               SP                      145.120000
# Conj. Paracatu               MG                      132.000000
# Conj. Calcário               CE                      132.000000
# Conj. Juazeiro Solar         BA                      120.000000
# Conj. Luzia                  PB                      117.888000
# Conj. Francisco Sá           MG                      105.000000
# Conj. Ciranda                PE                       96.000000
# Conj. Sertão Solar Barreiras BA                       94.640000
# Conj. Jaíba                  MG                       93.500000
# Conj. Pedranópolis           SP                       90.360000
# Conj. Araxá                  MG                       88.400000
# Conj. Floresta               RN                       86.000000
# Conj. Sol do Futuro          CE                       81.000000
# Conj. Dracena                SP                       81.000000
# Conj. Horizonte              BA                       77.400000
# Conj. Bom Jesus              BA                       60.000000
# Conj. Lapa                   BA                       60.000000
# Conj. São Pedro              BA                       54.000000
# Conj. BJL                    BA                       40.000000
# Assú V                       RN                       34.000000
# Conj. Tacaratu (Solar)       PE                       10.000000
# Flor de Mandacaru            CE                        2.000000
#
#                                         val_latitudesecoletora  \
# nom_usina_conjunto           id_estado
# Conj. Janaúba                MG                     -15.946560
# Conj. São Gonçalo            PI                     -10.103855
# Conj. Lar do Sol             MG                     -17.363171
# Conj. Sol do Sertão          BA                     -12.239130
# Conj. Pirapora               MG                     -17.405600
# Conj. Alex                   CE                      -5.269671
# Conj. Serra do Mel C         RN                      -5.131425
# Conj. BJL                    BA                      -43.463640
# Assú V                       RN                      -37.026390
# Conj. Tacaratu (Solar)       PE                      -38.131647
# Flor de Mandacaru            CE                      -37.305556

# %%
group_by_usina_solar.dropna().groupby(['id_estado']).agg(n_usinas_solares=('val_capacidadeinstalada', 'count'))
# Out:
#            n_usinas_solares
# id_estado
# BA                       10
# CE                        5
# MG                        7
# PB                        2
# PE                        3
# PI                        5
# RN                        3
# SP                        6

# %%
group_by_usina_eolica.query('id_estado=="RN"').sort_index()
# Out:
#                                         val_capacidadeinstalada  \
# nom_usina_conjunto           id_estado
# Alegria I                    RN                          51.000
# Alegria II                   RN                         100.650
# Conj. Acauã                  RN                          16.800
# Conj. Afonso Bezerra         RN                         159.600
# Conj. Amazonas               RN                         250.485
# Conj. Anemus                 RN                          63.000
# Conj. Areia Branca           RN                          50.400
# Conj. Asa Branca             RN                         160.000
# Conj. Aventura               RN                         105.000
# Conj. Baixa do Feijão        RN                         218.700
# Conj. Bloco Sul              RN                         155.400
# Conj. Brisa Potiguar I       RN                         183.600
# Conj. Cabeço Preto II        RN                         146.200
# Conj. Caju                   RN                         233.700
# Conj. Calango 1              RN                          60.000
# Conj. Calango 2              RN                          90.000
# Conj. Calango 3              RN                          84.000
# Conj. Campo dos Ventos       RN                         105.600
# Conj. Carcará II             RN                          90.000
# Conj. Carnaúbas              RN                         108.000
# Conj. Cumaru                 RN                         205.800
# Conj. Cutia                  RN                         312.900
# Conj. Filgueira              RN                          67.450
# Conj. Gameleira              RN                          81.650
# Conj. Jandaíra I             RN                          90.090
# Conj. Jerusalém              RN                         260.400
# Conj. Macacos                RN                          78.200
# Conj. Mangue Seco            RN                         104.000
# Conj. Modelo                 RN                          56.400
# Conj. Monte Verde            RN                         319.200
# Conj. Monte do Ronca         RN                         256.410
# Conj. Morro dos Ventos       RN                         171.800
# Conj. Morro dos Ventos II    RN                          89.160
# Conj. Olho d'Água            RN                          94.000
# Conj. Renascença             RN                         150.000
# Conj. Renascença V           RN                          60.000
# Conj. Riachão                RN                         145.800
# Conj. Rio do Vento           RN                         487.200
# Conj. Rio do Vento Expansão  RN                         219.700
# Conj. Santa Clara            RN                         188.000
# Conj. Santa Rosa Mundo Novo  RN                         155.400
# Conj. Santo Agostinho        RN                          86.800
# Conj. Serra de Santana 1 e 2 RN                          96.000
# Conj. Serra de Santana 3     RN                         108.000
# Conj. Serra do Mel A         RN                         287.190
# Conj. Serra do Mel B         RN                         273.000
# Conj. Serra do Mel C         RN                         268.310
# Conj. Serra do Mel II A      RN                         211.365
# Conj. Serra do Mel II B      RN                         205.800
# Conj. São Miguel             RN                          60.375
# Conj. Terra Santa            RN                          92.300
# Conj. União dos Ventos       RN                         234.700
# Miassaba 3                   RN                          68.470
# Rei dos Ventos 1             RN                          58.450
# Rei dos Ventos 3             RN                          60.120
#
#                                         val_latitudesecoletora  \
# nom_usina_conjunto           id_estado
# Alegria I                    RN                      -5.115283
# Alegria II                   RN                      -5.097279
# Conj. Acauã                  RN                            NaN
# Conj. Afonso Bezerra         RN                      -5.324612
# Conj. Amazonas               RN                      -5.016667
# Conj. Anemus                 RN                            NaN
# Conj. Areia Branca           RN                      -4.963689
# Conj. Filgueira              RN                      -36.996667
# Conj. Gameleira              RN                      -35.487993
# Conj. Jandaíra I             RN                      -36.019137
# Conj. Jerusalém              RN                      -36.121698
# Conj. Macacos                RN                      -35.848341
# Conj. Mangue Seco            RN                      -36.359399
# Conj. Modelo                 RN                      -35.896944
# Conj. Monte Verde            RN                      -36.201060
# Conj. Monte do Ronca         RN                      -36.031974
# Conj. Morro dos Ventos       RN                      -35.884864
# Conj. Morro dos Ventos II    RN                      -35.884986
# Conj. Olho d'Água            RN                      -35.977483
# Conj. Renascença             RN                      -35.886385
# Conj. Renascença V           RN                      -35.868772
# Conj. Riachão                RN                      -35.447243
# Conj. Rio do Vento           RN                      -35.960820
# Conj. Rio do Vento Expansão  RN                      -36.113236
# Conj. Santa Clara            RN                      -35.920164
# Conj. Santa Rosa Mundo Novo  RN                      -36.156221
# Conj. Santo Agostinho        RN                      -36.218006
# Conj. Serra de Santana 1 e 2 RN                      -36.577500
# Conj. Serra de Santana 3     RN                      -36.498056
# Conj. Serra do Mel A         RN                      -37.049532
# Conj. Serra do Mel B         RN                      -37.049532
# Conj. Serra do Mel C         RN                      -37.049532
# Conj. Serra do Mel II A      RN                      -37.113856
# Conj. Serra do Mel II B      RN                      -37.113856
# Conj. São Miguel             RN                      -35.786178
# Conj. Terra Santa            RN                      -36.057486
# Conj. União dos Ventos       RN                      -35.886111
# Miassaba 3                   RN                      -36.449722
# Rei dos Ventos 1             RN                      -36.202069
# Rei dos Ventos 3             RN                      -36.163206

# %%
group_by_usina_eolica.dropna().groupby(['id_estado']).agg(n_usinas_eolicas=('val_capacidadeinstalada', 'count'))
# Out:
#            n_usinas_eolicas
# id_estado
# BA                       51
# CE                       21
# MA                        1
# PB                        4
# PE                        6
# PI                       17
# RN                       52
# RS                       11
# SC                        2

# %% [markdown]
# # Preparando dados para plotagem dos mapas

# %%
lon_solar = group_by_usina_solar.dropna()['val_longitudesecoletora'].values
lat_solar = group_by_usina_solar.dropna()['val_latitudesecoletora'].values
values_solar = group_by_usina_solar.dropna()['val_capacidadeinstalada'].values

# %%
lon_eolica = group_by_usina_eolica.dropna()['val_longitudesecoletora'].values
lat_eolica = group_by_usina_eolica.dropna()['val_latitudesecoletora'].values
values_eolica = group_by_usina_eolica.dropna()['val_capacidadeinstalada'].values

# %% [markdown]
# # Plotagem dos mapas

# %%
fig, ax = plt.subplots()

m = Basemap(projection='merc', llcrnrlat=-35, urcrnrlat=7,
            llcrnrlon=-77, urcrnrlon=-32, resolution='i')
m.ax = ax
line_color = '#cccccc'
wather_color = '#f2f2f2'

m.drawcoastlines(color=line_color, linewidth=0.1)
#m.fillcontinents(color=line_color,lake_color=wather_color, zorder=1)
m.drawmapboundary(color=line_color, fill_color=wather_color, zorder=0)

fig.set_size_inches(18, 18)

m.readshapefile('Brasil\\gadm41_BRA_1', 'estados', zorder=5)

m.readshapefile('Brasil\\gadm41_BRA_0', 'pais', zorder=5)



x_solar, y_solar = m(lon_solar, lat_solar)

sc = m.scatter(x_solar, y_solar, zorder=10, color='#37888D', s=60, linewidths=1, edgecolor='black',)



x_eolica, y_eolica = m(lon_eolica, lat_eolica)

sc = m.scatter(x_eolica, y_eolica, zorder=9, marker='s', color='blue', s=60, linewidths=1, edgecolor='black',)


patches = [Polygon(np.array(m.pais[0]))]

pc = PatchCollection(patches, facecolor= '#ffd699', edgecolor='k', linewidths=0.01, zorder=2)
ax.add_collection(pc)


markers=['o','s']
colors=['#37888D', 'blue']
h = [plt.scatter([],[], color=colors[j], marker=markers[j], s=i, edgecolors='k') for j,i in enumerate([60,60])]
leg = plt.legend(handles=h, labels=['Solar','Eólica'],loc='upper right', title="Usinas", fontsize=13,title_fontsize=13)

#leg._legend_box.align = "center"


plt.savefig('FIGURAS\\MAPA_S.svg')

# %%
fig, ax = plt.subplots()

m = Basemap(projection='merc', llcrnrlat=-23.2, urcrnrlat=-3,
            llcrnrlon=-55, urcrnrlon=-34.5, resolution='i')
m.ax = ax
line_color = '#cccccc'
wather_color = '#ccf5ff'

m.drawcoastlines(color=line_color, linewidth=0.1)
#m.fillcontinents(color=line_color,lake_color=wather_color, zorder=1)
m.drawmapboundary(color=line_color, fill_color=wather_color, zorder=0)

fig.set_size_inches(18, 18)

m.readshapefile('Brasil\\gadm41_BRA_1', 'estados', zorder=5)

m.readshapefile('Brasil\\gadm41_BRA_0', 'pais', zorder=5)

x_solar, y_solar = m(lon_solar, lat_solar)

sc = m.scatter(x_solar, y_solar, s=values_solar, c=values_solar, zorder=10, cmap=sns.color_palette("crest", as_cmap=True)
, linewidths=1, edgecolor='black',)

patches = [Polygon(np.array(m.pais[0]))]

pc = PatchCollection(patches, facecolor= '#ffd699', edgecolor='k', linewidths=0.01, zorder=2)
ax.add_collection(pc)

colors = ['#2B3372', '#37888D', '#66AD90', '#99C791']

h = [plt.scatter([],[], color=colors[j], marker="o", s=i, edgecolors='k') for j,i in enumerate([1000,500,200,50])]
leg = plt.legend(handles=h, labels=['1000 MW', '500 MW','200 MW','50 MW'],loc='upper left', title="Usinas Solares", labelspacing=2, fontsize=13,title_fontsize=13, framealpha=1)



plt.savefig('FIGURAS\\MAPA_B.svg')

# %%
fig, ax = plt.subplots()

m = Basemap(projection='merc', llcrnrlat=-35, urcrnrlat=7,
            llcrnrlon=-77, urcrnrlon=-32, resolution='i')
m.ax = ax
line_color = '#cccccc'
wather_color = '#ffffff'

m.drawcoastlines(color=line_color, linewidth=0.1)
#m.fillcontinents(color=line_color,lake_color=wather_color, zorder=1)
m.drawmapboundary(color=line_color, fill_color=wather_color, zorder=0)

fig.set_size_inches(18.5, 10.5)

m.readshapefile('Brasil\\gadm41_BRA_1', 'estados', zorder=5)

m.readshapefile('Brasil\\gadm41_BRA_0', 'pais', zorder=5)

x_solar, y = m(lon_solar, lat_solar)

sc = m.scatter(x_solar, y, s=values_solar, c=values_solar, zorder=10, cmap=sns.dark_palette("#69d", reverse=True, as_cmap=True)
, linewidths=1, edgecolor='black',)

patches = [Polygon(np.array(m.pais[0]))]

pc = PatchCollection(patches, facecolor= '#ffd699', edgecolor='k', linewidths=0.01, zorder=2)
ax.add_collection(pc)

h = [plt.scatter([],[], color="#0059b3", marker="o", s=i, edgecolors='k') for i in [1000,500,200,50]]
leg = plt.legend(handles=h, labels=['1000 MW', '500 MW','200 MW','50 MW'],loc='lower left', title="Usinas Fotovoltaicas", labelspacing=2, fontsize=13,title_fontsize=13)

leg._legend_box.align = "center"


plt.savefig('FIGURAS\\MAPA.svg')

# %%
lista_usinas = group_by_usina_solar.index.get_level_values('nom_usina_conjunto')

# %% [markdown]
# # Evolução de capacidade instalada

# %%
plot_df = pd.DataFrame()
plot_df['Solar'] = main_df.query('nom_tipousina=="Solar"').groupby(['din_instante']).agg({'val_capacidadeinstalada':'sum'})['val_capacidadeinstalada']

plot_df['Eólica'] = main_df.query('nom_tipousina=="Eólica"').groupby(['din_instante']).agg({'val_capacidadeinstalada':'sum'})['val_capacidadeinstalada']

# %%
(plot_df/1000).plot(xlabel='', ylabel='Capacidade Instalada (Gw)', figsize=(13,8))
# Out:
# <AxesSubplot:ylabel='Capacidade Instalada (Gw)'>

# %%
fig, ax = plt.subplots()
(plot_df/1000).resample('Y').agg([lambda x: x[-1] - x[0]]).plot(kind='bar', ax=ax, xlabel='', figsize=(10,8))

lista_ticks = plot_df.resample('Y').agg(['first','last']).index

ax.set_xticklabels([datetime.datetime.strftime(data, '%Y') for data in lista_ticks])

ax.legend(title='Fonte', labels=['Solar','Eólica'])

ax.xaxis.set_tick_params(rotation=50)
ax.set_ylabel('Aumento da Capacidade Instalada (GW)')
# Out:
# Text(0, 0.5, 'Aumento da Capacidade Instalada (GW)')

# %%
main_df.query('nom_tipousina=="Eólica"').groupby(['din_instante']).agg({'val_capacidadeinstalada':'sum'})
# Out:
#                      val_capacidadeinstalada
# din_instante
# 2022-01-01 00:00:00               19748.2252
# 2022-01-01 01:00:00               19748.2252
# 2022-01-01 02:00:00               19748.2252
# 2022-01-01 03:00:00               19748.2252
# 2022-01-01 04:00:00               19748.2252
# ...                                      ...
# 2023-04-19 19:00:00               25237.3052
# 2023-04-19 20:00:00               25237.3052
# 2023-04-19 21:00:00               25237.3052
# 2023-04-19 22:00:00               25237.3052
# 2023-04-19 23:00:00               25237.3052
#
# [11376 rows x 1 columns]

# %% [markdown]
# # Plot de dias específicos onde grandes usinas solares tiveram grande variação na geração

# %%
main_df.pipe(get_usina_solar_pipeline, nome_usina='Conj. São Gonçalo')[['val_geracaoprogramada','val_geracaoverificada','val_capacidadeinstalada']].loc[lambda x: (x.index.day==28)&(x.index.month==2)&(x.index.year==2023)].plot( ylabel='Potência (MW)')
# Out:
# <AxesSubplot:xlabel='din_instante', ylabel='Potência (MW)'>

# %%
conjunto_janauba_df[['val_geracaoprogramada','val_geracaoverificada']].loc[lambda x: (x.index.day==19)&(x.index.month==3)].plot()
# Out:
# <AxesSubplot:xlabel='din_instante'>

# %%
conjunto_janauba_df[['val_geracaoprogramada','val_geracaoverificada']].loc[lambda x: (x.index.day==30)&(x.index.month==10)].plot()
# Out:
# <AxesSubplot:xlabel='din_instante'>

# %%
conjunto_janauba_df[['val_geracaoprogramada','val_geracaoverificada']].loc[lambda x: (x.index.day==20)&(x.index.month==12)].plot()
# Out:
# <AxesSubplot:xlabel='din_instante'>

# %%
conjunto_janauba_df[['val_geracaoprogramada','val_geracaoverificada']].loc[lambda x: (x.index.day==11)&(x.index.month==1)&(x.index.year==2023)].plot()
# Out:
# <AxesSubplot:xlabel='din_instante'>
